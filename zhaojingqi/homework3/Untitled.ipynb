# %%
import urllib2
from bs4 import BeautifulSoup

# %%
url="http://mp.weixin.qq.com/s?__biz=MzA5MzE5MTUwNQ==&mid=2650476640&idx=1&sn=9f16166fa75185e6adabcbc1fea3f6bf&scene=23&srcid=04201XoB3E2B8Re8I7CyLTXb#rd"
content=urllib2.urlopen(url).read()
soup=BeautifulSoup(content,'html.parser')
print soup.title.text
print soup.find('div',{'class','rich_media_meta_list'}).find(id='post-date').text
print soup.find('div',{'class','rich_media_content'}).get_text()
# Out:
# X光脱毛：女人要对自己狠一点儿（时尚深坑）
# 2016-04-16
#
# ...
